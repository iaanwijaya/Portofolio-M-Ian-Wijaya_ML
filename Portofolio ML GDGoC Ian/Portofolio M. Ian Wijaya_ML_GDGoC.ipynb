# %% [markdown]
# ## **Heart Disease** **Prediction**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Processing

# %% [markdown]
# **Data Wrangling**

# %%
# loading the csv data to a Pandas DtaFrame
heart_data = pd.read_csv('D:\Portofolio ML GDGoC Ian\heart_disease_data.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7088\906390686.py:2: SyntaxWarning: invalid escape sequence '\P'
#   heart_data = pd.read_csv('D:\Portofolio ML GDGoC Ian\heart_disease_data.csv')

# %%
# print first 5 row of the dataset
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# print last 5 rows of the dataset
heart_data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
# number of rows and colums in the dataset
heart_data.shape
# Out:
# (303, 14)

# %%
# getting some informations about the data
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# **Data Availibility Checking**

# %%
# checking for missing values
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# **Descriptive Statistics**

# %%
# statistical measures about the data
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# **Exaploratory Data Analysis**

# %%
# looking for correlation between variable (example)
import seaborn as sns
sns.heatmap(heart_data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **Data Visualization**

# %%
# Checking The Value of Sex
# 0---> female
# 1---> male

heart_data["sex"].value_counts().sort_values(ascending = False).plot(kind= "pie")
plt.title("Sex Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# From the data that we have, in this sample show that the population of male is more than female

# %%
# Sex Distribution by Heart Disease Status

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(heart_data[heart_data['target'] == 0]['sex'], bins=10, alpha=0.7, label='No Heart Disease', color='blue')
plt.hist(heart_data[heart_data['target'] == 1]['sex'], bins=10, alpha=0.7, label='Heart Disease', color='red')
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.title('Sex Distribution by Heart Disease Status')
_ = plt.legend()

# %% [markdown]
# From the histogram, we can conclud that the highest population that can have heart disease is occur on female than male, although male is more than female

# %%
# Age Distribution

heart_data["age"].value_counts().sort_values(ascending = False).plot(kind= "pie")
plt.title("Age Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# The sample that data use to be is from various ages, where the most common is at age 58 and the least at age 77

# %%
# Age Distribution by Heart Disease Status

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(heart_data[heart_data['target'] == 0]['age'], bins=10, alpha=0.7, label='No Heart Disease', color='blue')
plt.hist(heart_data[heart_data['target'] == 1]['age'], bins=10, alpha=0.7, label='Heart Disease', color='red')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution by Heart Disease Status')
_ = plt.legend()

# %% [markdown]
# Heart disease is closely associated with the age range of 30-70 years, as the risk increases with age. Key risk factors include high blood pressure, high cholesterol, diabetes, obesity, and unhealthy lifestyles (smoking, lack of exercise). Prevention involves maintaining a healthy diet, regular exercise, stress management, and routine health check-ups. Adopting a healthy lifestyle can significantly reduce the risk of heart disease.

# %%
# Age by Sex Distribution

heart_data.groupby("sex")["age"].mean().sort_values(ascending= False).plot(kind="bar")
plt.title("Age by Sex Distribution")
plt.xlabel("Sex")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# In summary, the risk and symptoms of heart disease differ between men and women. Men are more vulnerable at a younger age, while women are at higher risk after menopause. Women's symptoms are often less specific, and risk factors can affect both genders differently. Prevention and treatment approaches should be tailored to each gender for better effectiveness.

# %%
# Correlative Between Variable

plt.figure(figsize=(15, 15))
plt.title("Correlation Between Variable")

categorical_val = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

for i, column in enumerate(categorical_val, 1):
    plt.subplot(3, 3, i)

    heart_data[heart_data["target"] == 0][column].hist(bins=35, color='blue', label='Have Heart Disease = NO', alpha=0.6)
    heart_data[heart_data["target"] == 1][column].hist(bins=35, color='red', label='Have Heart Disease = YES', alpha=0.6)
    plt.legend()
    plt.xlabel(column)

plt.show()

# %% [markdown]
# 1. cp (chest pain): People with cp 1, 2, 3 are more likely to have heart disease than people with cp 0.
# 2. restecg (resting EKG results): People with a value of 1 (reporting an abnormal heart rhythm, which can range from mild symptoms to severe problems) are more likely to have heart disease.
# 3. exang (exercise-induced angina): people with a value of 0 (No ==> angina induced by exercise) have more heart disease than people with a value of 1 (Yes ==> angina induced by exercise)
# 4. slope (the slope of the ST segment of peak exercise): People with a slope value of 2 (Downslopins: signs of an unhealthy heart) are more likely to have heart disease than people with a slope value of 2 slope is 0 (Upsloping: best heart rate with exercise) or 1 (Flatsloping: minimal change (typical healthy heart)).
# 5. ca (number of major vessels (0-3) stained by fluorocopy): the more blood movement the better, so people with ca equal to 0 are more likely to have heart disease.
# 6. thal (thalium stress result): People with a thal value of 2 (defect corrected: once was a defect but ok now) are more likely to have heart disease.

# %%
# Age vs Cholesterol Levels by Heart Disease Status

plt.figure(figsize=(8, 6))
plt.scatter(heart_data[heart_data['target'] == 0]['age'], heart_data[heart_data['target'] == 0]['chol'], color='blue', label='No Heart Disease', alpha=0.6)
plt.scatter(heart_data[heart_data['target'] == 1]['age'], heart_data[heart_data['target'] == 1]['chol'], color='red', label='Heart Disease', alpha=0.6)

plt.xlabel('Age')
plt.ylabel('Cholesterol Levels (chol)')
plt.title('Age vs. Cholesterol Levels by Heart Disease Status')
_ = plt.legend()

# %% [markdown]
# Age and cholesterol levels are strongly linked to heart disease. As age increases, cholesterol management becomes more challenging, amplifying the risk of cardiovascular problems. Preventive measures, including lifestyle changes, regular health check-ups, and, if necessary, medications, can significantly reduce the risk.

# %%
# Resting Blood Pressure and Heart Disease by Sex

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='target', y='trestbps', hue='sex', data=heart_data, palette=['blue', 'red'])
plt.xlabel('Heart Disease Status')
plt.ylabel('Resting Blood Pressure (mm Hg)')
plt.title('Resting Blood Pressure and Heart Disease by Sex')
plt.xticks([0, 1], ['No Heart Disease', 'Heart Disease'])
_ = plt.legend(title='Sex', loc='upper right')

# %% [markdown]
# * If there is no heart disease, a female have more resting blood preasure (mm Hg) high than a male
# * If there is heart disease, either it is a female or a male, they may have equal resting blood preasure (mm Hg)

# %% [markdown]
# **Machine Learning**

# %%
# checking the distributions of the Traget Variable
heart_data['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# * **1** ---> Deactive Heart
# * **0** ---> Healthy Heart

# %% [markdown]
# Splitting the Features and Target

# %%
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# %%
print(X)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %% [markdown]
# Splitting the Data into Training Data & Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the LogisticRegressions model with Training data
model.fit(X_train, Y_train)
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data: ', training_data_accuracy)
# Out:
# Accuracy on Training data:  0.8512396694214877

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data: ', test_data_accuracy)
# Out:
# Accuracy on Test data:  0.819672131147541

# %% [markdown]
# Building Predictive System

# %%
# The example of streamlit App

input_data = (52,1,0,128,255,0,1,161,1,0,2,1,3)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are prediciting for only on instance
input_data_reshape= input_data_as_numpy_array.reshape(1, -1)

prediction = model.predict(input_data_reshape)

print(prediction)

if (prediction[0]==0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [0]
# The Person does not have a Heart Disease
# c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Save Model

# %%
import joblib
joblib.dump(model, "linearmodel.pkl")
# Out:
# ['linearmodel.pkl']
